# %% [markdown]
# OLYMPUS-TensorFlow interoperation with OLYMPUS2TF
# ===========================================
#
# Link: go/olympus2tf-colab
#
# The OLYMPUS2TF colab has been deprecated, and the example code has
# been moved to [olympus2tf/examples](https://github.com/olympus-ml/olympus/tree/main/olympus/experimental/olympus2tf/examples).
